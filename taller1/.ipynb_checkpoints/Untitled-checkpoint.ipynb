# %% [markdown]
# # taller 1
# ## Isaac Arias, Bastian Alvarez

# %% [markdown]
# #### funciones de verificacion para bibliotecas
# Estas funciones son cuadno no se encuentran instaladas las bibliotecas
# y se instalan automaticamente

# %%
def verificaionPanda():
    try:
        import pandas as pd
    except ImportError:
        import subprocess
        import sys
        print("🔄 pandas no está instalado. Instalando Pandas, espere un momento...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", "pandas"])
        print("✅ pandas instalado correctamente.")



def verificacionNumpy():
    try:
        import numpy as np
    except ImportError:
        import subprocess
        import sys
        print("🔄 numpy no está instalado. Instalando...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", "numpy"])
        import numpy as np
        print("✅ numpy instalado correctamente.")

def importacionDeBibliotecasAutomaticas():
    verificacionPanda()

# %% [markdown]
# #### Codigo para separar los archivos en variables
#
# se declaran los 4 archivos para su posterior uso

# %%
importacionDeBibliotecasAutomaticas()
import pandas as pd
import numpy as np
#se usa bravo como "B", charlie como "C" y delta como "D"
#archivos de codigos
archCodeBravo = 'Libro_CódigosADM2025_ArchivoB.xlsx'
archCodeCharlie = 'Libro_CódigosADM2025_ArchivoC.xlsx'
archCodeDelta = 'Libro_CódigosADM2025_ArchivoD.xlsx'

#archivos de informacion importante
archBravo = 'ArchivoB_Adm2025.csv'
archCharlie = 'ArchivoC_Adm2025.csv'
archDelta = 'ArchivoD_Adm2025.csv'

print("Asignacion de archivos a variables correctaemte ejecutada")
# Out:
# ✅ pandas ya está instalado.
# Asignacion de archivos a variables correctaemte ejecutada
